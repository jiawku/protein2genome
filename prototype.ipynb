# %% [markdown]
# #### This is the notebook I used to build up the libary's core funcion.
# #### I also used it to read the gff3 file from genecode project to create the feature dataframe and save as parquet file in the resources folder.

# %%
from io import StringIO
from os import PathLike
from pathlib import Path
import gzip
import logging
import pandas as pd


def read_gff3_to_df(feature_file_path: PathLike) -> pd.DataFrame:
    # Define the columns in the GFF3 file
    GFF3_columns=["Sequence ID","source","Feature Type","Feature Start","Feature End","Score","Strand","Phase","INFO"]
    
    # Check if the file is gzipped or not
    if feature_file_path.suffix==".gz":
        FILE=gzip.open(feature_file_path, 'r')
    elif feature_file_path.suffix==".gff3" or feature_file_path.suffix==".gff":
        FILE=open(feature_file_path, 'r')
    else:
        raise ValueError(f"The file {feature_file_path} is not a recognized file type. Please provide a .gz, .gff3 or .gff file.")
        
    with FILE as file:
        outlist=list()
        for line in file.readlines():
            line=line.decode().strip()
            if not line.startswith("#"):
                # Parse the line and create a dictionary
                parsed_dict=dict(zip(GFF3_columns,line.split("\t")))
                # Parse the INFO field and create a dictionary
                INFO_dict=dict([item.split("=") for item in parsed_dict["INFO"].split(";")])
                # Update the parsed dictionary with the INFO dictionary
                parsed_dict.update(INFO_dict)
                parsed_dict.pop("INFO")
                outlist.append(parsed_dict)

    return pd.DataFrame(outlist)

# Define the file paths for GRCh38 and GRCh37 GFF3 files
gencode_Grch38_path = Path("resources/gencode.v45.basic.annotation.gff3.gz")
gencode_Grch37_path = Path("resources/gencode.v45lift37.basic.annotation.gff3.gz")

# Read the GRCh38 GFF3 file into a DataFrame
grch38_df = read_gff3_to_df(gencode_Grch38_path)

# Read the GRCh37 GFF3 file into a DataFrame
grch37_df = read_gff3_to_df(gencode_Grch37_path)

# %%
# This is the cell used to create the CDS DataFrame and save it to a parquet file.
cds_grch38_df=grch38_df[grch38_df["Feature Type"]=="CDS"].copy()
cds_grch38_df["Genome_Build"]="GRCh38" 


cds_grch37_df=grch37_df[grch37_df["Feature Type"]=="CDS"].copy()
cds_grch37_df["Genome_Build"]="GRCh37"

cds_dfs=pd.concat([cds_grch38_df,cds_grch37_df])

cds_dfs.reset_index(drop=True, inplace=True)

cds_dfs.to_parquet("resources/genecode_CDS_DataFrame.parquet")

# %%
cds_dfs
# Out:
#         Sequence ID   source Feature Type Feature Start Feature End Score  \
# 0              chr1   HAVANA          CDS         65565       65573     .
# 1              chr1   HAVANA          CDS         69037       70008     .
# 2              chr1   HAVANA          CDS        450740      451678     .
# 3              chr1   HAVANA          CDS        685716      686654     .
# 4              chr1   HAVANA          CDS        924432      924948     .
# ...             ...      ...          ...           ...         ...   ...
# 1311174        chrM  ENSEMBL          CDS         10470       10766     .
# 1311175        chrM  ENSEMBL          CDS         10760       12137     .
# 1311176        chrM  ENSEMBL          CDS         12337       14148     .
# 1311177        chrM  ENSEMBL          CDS         14149       14673     .
# 1311178        chrM  ENSEMBL          CDS         14747       15887     .
#
#         Strand Phase                     ID              gene_id  ...  \
# 0            +     0  CDS:ENST00000641515.2    ENSG00000186092.7  ...
# 1            +     0  CDS:ENST00000641515.2    ENSG00000186092.7  ...
# 2            -     0  CDS:ENST00000426406.4    ENSG00000284733.2  ...
# 3            -     0  CDS:ENST00000332831.5    ENSG00000284662.2  ...
# 4            +     0  CDS:ENST00000616016.5   ENSG00000187634.13  ...
# ...        ...   ...                    ...                  ...  ...
# 1311174      +     0  CDS:ENST00000361335.1  ENSG00000212907.2_2  ...
# 1311175      +     0  CDS:ENST00000361381.2  ENSG00000198886.2_2  ...
# 1311176      +     0  CDS:ENST00000361567.2  ENSG00000198786.2_2  ...
# 1311177      -     0  CDS:ENST00000361681.2  ENSG00000198695.2_4  ...
# 1311178      +     0  CDS:ENST00000361789.2  ENSG00000198727.2_2  ...
#
#         artif_dupl Genome_Build remap_status remap_num_mappings  \
# 0              NaN       GRCh38          NaN                NaN
# 1              NaN       GRCh38          NaN                NaN
# 2              NaN       GRCh38          NaN                NaN
# 3              NaN       GRCh38          NaN                NaN
# 4              NaN       GRCh38          NaN                NaN
# ...            ...          ...          ...                ...
# 1311174        NaN       GRCh37  full_contig                NaN
# 1311175        NaN       GRCh37  full_contig                NaN
# 1311176        NaN       GRCh37  full_contig                NaN
# 1311177        NaN       GRCh37  full_contig                NaN
# 1311178        NaN       GRCh37  full_contig                NaN
#
#         remap_target_status remap_original_location gene_status  \
# 0                       NaN                     NaN         NaN
# 1                       NaN                     NaN         NaN
# 2                       NaN                     NaN         NaN
# 3                       NaN                     NaN         NaN
# 4                       NaN                     NaN         NaN
# ...                     ...                     ...         ...
# 1311174                 NaN      chrM:+:10470-10766         NaN
# 1311175                 NaN      chrM:+:10760-12137         NaN
# 1311176                 NaN      chrM:+:12337-14148         NaN
# 1311177                 NaN      chrM:-:14149-14673         NaN
# 1311178                 NaN      chrM:+:14747-15887         NaN
#
#         remap_substituted_missing_target transcript_status remap_original_id
# 0                                    NaN               NaN               NaN
# 1                                    NaN               NaN               NaN
# 2                                    NaN               NaN               NaN
# 3                                    NaN               NaN               NaN
# 4                                    NaN               NaN               NaN
# ...                                  ...               ...               ...
# 1311174                              NaN               NaN               NaN
# 1311175                              NaN               NaN               NaN
# 1311176                              NaN               NaN               NaN
# 1311177                              NaN               NaN               NaN
# 1311178                              NaN               NaN               NaN
#
# [1311179 rows x 37 columns]

# %%
def convert_ProteinLoc_to_GenomicLoc(CDS_df: pd.DataFrame, transcript_id: str, protein_start: int, protein_end: int, genome_build: str) -> list:
    if genome_build == "hg19":
        genome_build = "GRCh37"
    elif genome_build == "hg38":
        genome_build = "GRCh38"
        
    transcript_df=CDS_df[CDS_df["transcript_id"].str.startswith(transcript_id) & (CDS_df["Genome_Build"]== genome_build)].copy()

    if transcript_df.empty:
        logging.error("No transcript found")
        return []
    elif transcript_df.iloc[0]["Strand"]=="+":
        transcript_df.sort_values("Feature Start",inplace=True)
    elif transcript_df.iloc[0]["Strand"]=="-":
        transcript_df.sort_values("Feature Start",inplace=True,ascending=False)

    transcript_df["length"]=transcript_df["Feature End"].astype(int)-transcript_df["Feature Start"].astype(int)+1
    transcript_df['CDS_start'] = (transcript_df.groupby('protein_id')['length'].cumsum() - transcript_df['length'])
    transcript_df['CDS_end'] = transcript_df.groupby('protein_id')['length'].cumsum()
    
    CDS_start, CDS_end = protein_start*3, protein_end*3

    overlap_CDS = transcript_df[(transcript_df["CDS_end"] >= CDS_start) & (transcript_df["CDS_start"] <= CDS_end)]

    if overlap_CDS.empty:
        logging.error("No overlap found")
        return[]
    elif overlap_CDS.iloc[0]["Strand"] == "-":
        chromosome = overlap_CDS.iloc[0]["Sequence ID"]
        genomic_start = int(overlap_CDS.iloc[-1]["Feature End"]) - (CDS_end - overlap_CDS.iloc[-1]["CDS_start"])+1
        genomic_end = int(overlap_CDS.iloc[0]["Feature End"]) - (CDS_start - overlap_CDS.iloc[0]["CDS_start"])+3
    elif overlap_CDS.iloc[0]["Strand"] == "+":
        chromosome = overlap_CDS.iloc[0]["Sequence ID"]
        genomic_start = int(overlap_CDS.iloc[0]["Feature Start"]) + (CDS_start - overlap_CDS.iloc[0]["CDS_start"])-3
        genomic_end = int(overlap_CDS.iloc[-1]["Feature Start"]) + (CDS_end - overlap_CDS.iloc[-1]["CDS_start"])-1
    else:
        logging.error("Format Error No strand info found in fearture file")
        return []
    
    return (chromosome,genomic_start,genomic_end)

# %%
test_input = StringIO("""Gene Symbol	Transcript ID	Genome Build	Protein Domains
CIC	ENST00000575354	GRCh37	High mobility groupbox domain: 199—269
CIC	ENST00000681038	GRCh38	High mobility groupbox domain : 199-269
BRCA1	ENST00000471181	GRCh37	Zincfinger, RING—type: 24—658;BRCA1 , serine—richdomain: 345—507
BRCA1	ENST00000357654	GRCh38	Zincfinger, RING—type: 24—658;BRCA1 , serine—richdomain: 345—507""")
protein_data = pd.read_csv(test_input, sep='\t')

output_list=list()
for index, row in protein_data.iterrows():
    for item in row["Protein Domains"].split(";"):
        
        domain_dict=dict()
        domain_dict["Domain Name"],domain_dict["protein_pos"]=item.split(":")
        domain_dict["protein_start"],domain_dict["protein_end"]=list(domain_dict["protein_pos"].replace("—","-").strip().split("-"))
        domain_dict.pop("protein_pos")

        genomic_loc=convert_ProteinLoc_to_GenomicLoc(cds_dfs,transcript_id=row["Transcript ID"],protein_start=int(domain_dict["protein_start"]),protein_end=int(domain_dict["protein_end"]),genome_build=row["Genome Build"])
        
        domain_dict["Gene Symbol"]=row["Gene Symbol"]
        domain_dict["Genome_Build"]=row["Genome Build"]
        domain_dict["Chrom"]=genomic_loc[0]
        domain_dict["Domain Coordinates"]=domain_dict["protein_start"]+"-"+domain_dict["protein_end"]
        domain_dict["AA Length"]=int(domain_dict["protein_end"])-int(domain_dict["protein_start"])+1
        domain_dict["Genomic Coordiantes"]=f"{genomic_loc[1]}-{genomic_loc[2]}"
        domain_dict["NUC Length"]=int(genomic_loc[2])-int(genomic_loc[1])+1
        
        output_list.append(domain_dict)

# %%
pd.DataFrame(output_list)[["Gene Symbol", "Genome_Build", "Chrom", "Domain Name", "Domain Coordinates", "AA Length", "Genomic Coordiantes", "NUC Length"]]
# Out:
#   Gene Symbol Genome_Build  Chrom                     Domain Name  \
# 0         CIC       GRCh37  chr19   High mobility groupbox domain
# 1         CIC       GRCh38  chr19  High mobility groupbox domain
# 2       BRCA1       GRCh37  chr17           Zincfinger, RING—type
# 3       BRCA1       GRCh37  chr17       BRCA1 , serine—richdomain
# 4       BRCA1       GRCh38  chr17           Zincfinger, RING—type
# 5       BRCA1       GRCh38  chr17       BRCA1 , serine—richdomain
#
#   Domain Coordinates  AA Length Genomic Coordiantes  NUC Length
# 0            199-269         71   42791709-42792003         295
# 1            199-269         71   42272378-42272590         213
# 2             24-658        635   41245574-41276044       30471
# 3            345-507        163   41246027-41246515         489
# 4             24-658        635   43093557-43124027       30471
# 5            345-507        163   43094010-43094498         489

# %%
transcript_id="ENST00000575354"
genome_build="GRCh37"
cds_dfs[cds_dfs["transcript_id"].str.startswith(transcript_id) & (cds_dfs["Genome_Build"]== genome_build)]
# Out:
#         Sequence ID  source Feature Type Feature Start Feature End Score  \
# 1236886       chr19  HAVANA          CDS      42788857    42788923     .
# 1236887       chr19  HAVANA          CDS      42790923    42791072     .
# 1236888       chr19  HAVANA          CDS      42791158    42791392     .
# 1236889       chr19  HAVANA          CDS      42791472    42791601     .
# 1236890       chr19  HAVANA          CDS      42791697    42791879     .
# 1236891       chr19  HAVANA          CDS      42791962    42792127     .
# 1236892       chr19  HAVANA          CDS      42793040    42793242     .
# 1236893       chr19  HAVANA          CDS      42793333    42793558     .
# 1236894       chr19  HAVANA          CDS      42794000    42794103     .
# 1236895       chr19  HAVANA          CDS      42794385    42795618     .
# 1236896       chr19  HAVANA          CDS      42795710    42795897     .
# 1236897       chr19  HAVANA          CDS      42796238    42796359     .
# 1236898       chr19  HAVANA          CDS      42796452    42796618     .
# 1236899       chr19  HAVANA          CDS      42796718    42797011     .
# 1236900       chr19  HAVANA          CDS      42797108    42797433     .
# 1236901       chr19  HAVANA          CDS      42797744    42797988     .
# 1236902       chr19  HAVANA          CDS      42798087    42798241     .
# 1236903       chr19  HAVANA          CDS      42798325    42798456     .
# 1236904       chr19  HAVANA          CDS      42798756    42798887     .
# 1236905       chr19  HAVANA          CDS      42798976    42799343     .
#
#         Strand Phase                     ID               gene_id  ...  \
# 1236886      +     0  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236887      +     2  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236888      +     2  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236889      +     1  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236890      +     0  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236891      +     0  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236892      +     2  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236893      +     0  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236894      +     2  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236895      +     0  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236896      +     2  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236897      +     0  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236898      +     1  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236899      +     2  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236900      +     2  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236901      +     0  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236902      +     1  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236903      +     2  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236904      +     2  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
# 1236905      +     2  CDS:ENST00000575354.6  ENSG00000079432.9_16  ...
#
#         artif_dupl Genome_Build remap_status remap_num_mappings  \
# 1236886        NaN       GRCh37  full_contig                NaN
# 1236887        NaN       GRCh37  full_contig                NaN
# 1236888        NaN       GRCh37  full_contig                NaN
# 1236889        NaN       GRCh37  full_contig                NaN
# 1236890        NaN       GRCh37  full_contig                NaN
# 1236891        NaN       GRCh37  full_contig                NaN
# 1236892        NaN       GRCh37  full_contig                NaN
# 1236893        NaN       GRCh37  full_contig                NaN
# 1236894        NaN       GRCh37  full_contig                NaN
# 1236895        NaN       GRCh37  full_contig                NaN
# 1236896        NaN       GRCh37  full_contig                NaN
# 1236897        NaN       GRCh37  full_contig                NaN
# 1236898        NaN       GRCh37  full_contig                NaN
# 1236899        NaN       GRCh37  full_contig                NaN
# 1236900        NaN       GRCh37  full_contig                NaN
# 1236901        NaN       GRCh37  full_contig                NaN
# 1236902        NaN       GRCh37  full_contig                NaN
# 1236903        NaN       GRCh37  full_contig                NaN
# 1236904        NaN       GRCh37  full_contig                NaN
# 1236905        NaN       GRCh37  full_contig                NaN
#
#         remap_target_status    remap_original_location gene_status  \
# 1236886                 NaN  chr19:+:42284705-42284771         NaN
# 1236887                 NaN  chr19:+:42286771-42286920         NaN
# 1236888                 NaN  chr19:+:42287006-42287240         NaN
# 1236889                 NaN  chr19:+:42287320-42287449         NaN
# 1236890                 NaN  chr19:+:42287545-42287727         NaN
# 1236891                 NaN  chr19:+:42287810-42287975         NaN
# 1236892                 NaN  chr19:+:42288888-42289090         NaN
# 1236893                 NaN  chr19:+:42289181-42289406         NaN
# 1236894                 NaN  chr19:+:42289848-42289951         NaN
# 1236895                 NaN  chr19:+:42290233-42291466         NaN
# 1236896                 NaN  chr19:+:42291558-42291745         NaN
# 1236897                 NaN  chr19:+:42292086-42292207         NaN
# 1236898                 NaN  chr19:+:42292300-42292466         NaN
# 1236899                 NaN  chr19:+:42292566-42292859         NaN
# 1236900                 NaN  chr19:+:42292956-42293281         NaN
# 1236901                 NaN  chr19:+:42293592-42293836         NaN
# 1236902                 NaN  chr19:+:42293935-42294089         NaN
# 1236903                 NaN  chr19:+:42294173-42294304         NaN
# 1236904                 NaN  chr19:+:42294604-42294735         NaN
# 1236905                 NaN  chr19:+:42294824-42295191         NaN
#
#         remap_substituted_missing_target transcript_status remap_original_id
# 1236886                              NaN               NaN               NaN
# 1236887                              NaN               NaN               NaN
# 1236888                              NaN               NaN               NaN
# 1236889                              NaN               NaN               NaN
# 1236890                              NaN               NaN               NaN
# 1236891                              NaN               NaN               NaN
# 1236892                              NaN               NaN               NaN
# 1236893                              NaN               NaN               NaN
# 1236894                              NaN               NaN               NaN
# 1236895                              NaN               NaN               NaN
# 1236896                              NaN               NaN               NaN
# 1236897                              NaN               NaN               NaN
# 1236898                              NaN               NaN               NaN
# 1236899                              NaN               NaN               NaN
# 1236900                              NaN               NaN               NaN
# 1236901                              NaN               NaN               NaN
# 1236902                              NaN               NaN               NaN
# 1236903                              NaN               NaN               NaN
# 1236904                              NaN               NaN               NaN
# 1236905                              NaN               NaN               NaN
#
# [20 rows x 37 columns]
